# %% [markdown]
# # CIFAR-10 Image Classification

# %% [markdown]
# ## References
# ###https://towardsdatascience.com/exploratory-data-analysis-ideas-for-image-classification-d3fc6bbfb2d2

# %%
# Import Libraries
import warnings
warnings.filterwarnings('ignore')
import os
import matplotlib.pyplot as plt
import time
import calendar
from six.moves import cPickle as pickle
import numpy as np
import cv2
from skimage.feature import hog
from sklearn.decomposition import PCA
from sklearn.metrics import confusion_matrix
from sklearn import svm
from sklearn.metrics import classification_report,accuracy_score
from math import ceil
import plotly.express as px

# %%
# General Parameters

imageSize = 32  
channels = 3    
classes = 10    
trainingDataSize = 50000    
testDataSize = 10000        
trainingDataFiles = ('./dataset/cifar-10-batches-py/data_batch_1', './dataset/cifar-10-batches-py/data_batch_2', './dataset/cifar-10-batches-py/data_batch_3', './dataset/cifar-10-batches-py/data_batch_4','./dataset/cifar-10-batches-py/data_batch_5') 
testDataFile = './dataset/cifar-10-batches-py/test_batch'

# %%
# Class values

label={}
label[0]='airplane' 
label[1]='automobile' 
label[2]='bird' 
label[3]='cat' 
label[4]='deer' 
label[5]='dog' 
label[6]='frog' 
label[7]='horse' 
label[8]='ship'
label[9]='truck'

# %%
def loadData(filename):
    '''
    Load the data from the given filename

    Parameters:
    -----------
    filename: string
        The name of the file containing the data to load

    Returns:
    --------
    theSet['data']:     array of images
    theSet['labels']:   array of labels
    '''
    f = open(filename, 'rb')
    theSet = pickle.load(f,encoding='latin1')
    f.close()

    return theSet['data'], theSet['labels']

# %%
def convertImages(origImages):
    '''
    Convert the images from CIFAR-10 format, to an array of 10000 images each is 32 X 32 X 3 size

    Parameters:
    -----------
    origImages: array
        array of images in the CIFAR-10 format

    Returns:
    --------
    images:     array of images each in 32 X 32 X 3 size
    '''
    images = np.reshape(origImages,(-1, channels, imageSize, imageSize))
    images = np.transpose(images, (0,2,3,1))

    return images

# %%
def loadTrainingData(filenames):
    '''
    Load all the training data from all files

    Parameters:
    -----------
    filenames: array of string
        An array The name of the file containing the data to load

    Returns:
    --------
    trainingImages: array of the training set images
    trainingLabels: array of the training set labels
    '''

    #Pre-allocate the arrays
    trainingImages = np.zeros(shape=[trainingDataSize, imageSize, imageSize, channels], dtype=np.uint8)
    trainingLabels = np.zeros(shape=[trainingDataSize], dtype=int)

    start=0
    for fileName in filenames:

      origImages, labels = loadData(fileName)
      images = convertImages(origImages)

      numOfImages = len(images)
      end = start + numOfImages
      # print(numOfImages)
      trainingImages[start:end, :] = images
      trainingLabels[start:end] = labels
      start = end

    return trainingImages, trainingLabels

# %%
def loadTestData(filename):
    '''
    Load the test data

    Parameters:
    -----------
    filename: string
        The name of the file containing the test data

    Returns:
    --------
    testImages: array of images of the test data
    testLabels: array of labels of the test data
    '''

    origTestImages, testLabels = loadData(filename)
    testImages = convertImages(origTestImages)

    return testImages, testLabels

# %%
def currentTime():
    '''
    Returns the current time in seconds since EPOC
    Used to measure how much time each phase took

    Returns:
    --------
    the current time in second since EPOC
    '''

    return calendar.timegm(time.gmtime())

# %%
from google.colab import drive
drive.mount('/content/Drive', force_remount=True)
# Out:
# Mounted at /content/Drive

# %%
# !mkdir -p "/content/dataset"
# !tar -xzf "/content/Drive/MyDrive/CIFAR-10/cifar-10-python.tar.gz" -C "/content/dataset"

# %%
print("Loading the training set..."),
tik = currentTime()
trainingImages, trainingLabels = loadTrainingData(trainingDataFiles)
print("Took: " + str(currentTime()-tik) + " sec" )
# Out:
# Loading the training set...
# Took: 0 sec

# %% [markdown]
# ## Take 5 images per image class for EDA

# %%
list_0 = []
list_1 = []
list_2 = []
list_3 = []
list_4 = []
list_5 = []
list_6 = []
list_7 = []
list_8 = []
list_9 = []

# %%
for i in range(trainingImages.shape[0]):

  if trainingLabels[i] == 0:
    list_0.append(trainingImages[i])

  if trainingLabels[i] == 1:
    list_1.append(trainingImages[i])
    
  if trainingLabels[i] == 2:
    list_2.append(trainingImages[i])
    
  if trainingLabels[i] == 3:
    list_3.append(trainingImages[i])
    
  if trainingLabels[i] == 4:
    list_4.append(trainingImages[i])
    
  if trainingLabels[i] == 5:
    list_5.append(trainingImages[i])
    
  if trainingLabels[i] == 6:
    list_6.append(trainingImages[i])
    
  if trainingLabels[i] == 7:
    list_7.append(trainingImages[i])
    
  if trainingLabels[i] == 8:
    list_8.append(trainingImages[i])
    
  if trainingLabels[i] == 9:
    list_9.append(trainingImages[i])

# %%
num=5

list_0 = list_0[:num]
list_1 = list_1[:num]
list_2 = list_2[:num]
list_3 = list_3[:num]
list_4 = list_4[:num]
list_5 = list_5[:num]
list_6 = list_6[:num]
list_7 = list_7[:num]
list_8 = list_8[:num]
list_9 = list_9[:num]

# %% [markdown]
# ## **Average Image**

# %%
def find_mean_img(full_mat, title):
  
    mean_img = np.mean(full_mat, axis = 0,dtype=int)
    mean_img = mean_img.reshape((32,32,3))
    
    plt.imshow(mean_img,cmap='Greys_r');
    plt.title(f'Average {title}')
    plt.axis('off')
    plt.show()

# %%
find_mean_img(list_0,label[0])

# %%
find_mean_img(list_1,label[1])

# %%
find_mean_img(list_2,label[2])

# %%
find_mean_img(list_3,label[3])

# %%
find_mean_img(list_4,label[4])

# %%
find_mean_img(list_5,label[5])

# %%
find_mean_img(list_6,label[6])

# %%
find_mean_img(list_7,label[7])

# %%
find_mean_img(list_8,label[8])

# %%
find_mean_img(list_9,label[9])

# %% [markdown]
# ##**Creating and visualizing HOG Features**

# %%
from skimage.transform import resize
def hog_vis(img):
  resized_img = resize(img, (128*4, 128*4))
  fd, hog_image = hog(resized_img, orientations=9, pixels_per_cell=(8, 8),
                	cells_per_block=(2, 2), visualize=True, multichannel=True)
  plt.axis("off")
  plt.imshow(hog_image, cmap="gray")
  plt.show()
  return fd

# %%
fd9=hog_vis(list_9[0])
print(label[9])
plt.axis("off")
plt.imshow(list_9[0], cmap="gray")
plt.show()
# Out:
# truck

# %%
fd8=hog_vis(list_8[2])
print(label[8])
plt.axis("off")
plt.imshow(list_8[2], cmap="gray")
plt.show()
# Out:
# ship

# %%
fd7=hog_vis(list_7[0])
print(label[7])
plt.axis("off")
plt.imshow(list_7[0], cmap="gray")
plt.show()
# Out:
# horse

# %%
fd6=hog_vis(list_6[1])
print(label[6])
plt.axis("off")
plt.imshow(list_6[1], cmap="gray")
plt.show()
# Out:
# frog

# %%
fd5=hog_vis(list_5[0])
print(label[5])
plt.axis("off")
plt.imshow(list_5[0], cmap="gray")
plt.show()
# Out:
# dog

# %%
fd4=hog_vis(list_4[2])
print(label[4])
plt.axis("off")
plt.imshow(list_4[2], cmap="gray")
plt.show()
# Out:
# deer

# %% [markdown]
# hog_vis(list_9[0])
# print(label[9])

# %%
fd3=hog_vis(list_3[2])
print(label[3])
plt.axis("off")
plt.imshow(list_3[2], cmap="gray")
plt.show()
# Out:
# cat

# %%
fd2=hog_vis(list_2[2])
print(label[2])
plt.axis("off")
plt.imshow(list_2[2], cmap="gray")
plt.show()
# Out:
# bird

# %%
fd1=hog_vis(list_1[0])
print(label[1])
plt.axis("off")
plt.imshow(list_1[0], cmap="gray")
plt.show()
# Out:
# automobile

# %%
fd0=hog_vis(list_0[0])
print(label[0])
plt.axis("off")
plt.imshow(list_0[0], cmap="gray")
plt.show()
# Out:
# airplane

# %% [markdown]
# ```
#
# ```
#
# ## **PCA visualization**

# %%
def plot_pca(imageSet):
  
  pca = PCA()
  components = pca.fit_transform(imageSet)
  labels = {
      str(i): f"PC {i+1} ({var:.1f}%)"
      for i, var in enumerate(pca.explained_variance_ratio_ * 100)
  }

  classLabels=[]
  for i in range(10):
    classLabels.append(label[i])

  fig = px.scatter_3d(components,labels=labels, x=1, y=2, z=3, color=classLabels)
  fig.show()

# %%
def plot_pca_matrix(imageSet):
  
  pca = PCA()
  components = pca.fit_transform(imageSet)
  labels = {
      str(i): f"PC {i+1} ({var:.1f}%)"
      for i, var in enumerate(pca.explained_variance_ratio_ * 100)
  }

  classLabels=[]
  for i in range(10):
    classLabels.append(label[i])

  fig = px.scatter_matrix(
      components,
      labels=labels,
      dimensions=range(4),
      color=classLabels
  )
  fig.update_traces(diagonal_visible=False)
  fig.show()

# %%
imageSet = np.array([fd0,fd1,fd2,fd3,fd4,fd5,fd6,fd7,fd8,fd9])

# %%
plot_pca(imageSet)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="2ec6de72-5c79-43cc-997f-5b6f4a37c338" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2ec6de72-5c79-43cc-997f-5b6f4a37c338")) {                    Plotly.newPlot(                        "2ec6de72-5c79-43cc-997f-5b6f4a37c338",                        [{"hovertemplate":"color=airplane<br>PC 2 (11.9%)=%{x}<br>PC 3 (11.5%)=%{y}<br>PC 4 (11.4%)=%{z}<extra></extra>","legendgroup":"airplane","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"airplane","scene":"scene","showlegend":true,"x":[-10.828513980991007],"y":[32.95199824690314],"z":[14.785141189750895],"type":"scatter3d"},{"hovertemplate":"color=automobile<br>PC 2 (11.9%)=%{x}<br>PC 3 (11.5%)=%{y}<br>PC 4 (11.4%)=%{z}<extra></extra>","legendgroup":"automobile","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"automobile","scene":"scene","showlegend":true,"x":[-20.420189630532064],"y":[4.846001958161038],"z":[10.124161166470097],"type":"scatter3d"},{"hovertemplate":"color=bird<br>PC 2 (11.9%)=%{x}<br>PC 3 (11.5%)=%{y}<br>PC 4 (11.4%)=%{z}<extra></extra>","legendgroup":"bird","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"bird","scene":"scene","showlegend":true,"x":[-13.836380604637654],"y":[-21.815197459404665],"z":[-9.728295070870267],"type":"scatter3d"},{"hovertemplate":"color=cat<br>PC 2 (11.9%)=%{x}<br>PC 3 (11.5%)=%{y}<br>PC 4 (11.4%)=%{z}<extra></extra>","legendgroup":"cat","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"cat","scene":"scene","showlegend":true,"x":[27.45881721715061],"y":[8.898725316812206],"z":[-14.71353453068372],"type":"scatter3d"},{"hovertemplate":"color=deer<br>PC 2 (11.9%)=%{x}<br>PC 3 (11.5%)=%{y}<br>PC 4 (11.4%)=%{z}<extra></extra>","legendgroup":"deer","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"deer","scene":"scene","showlegend":true,"x":[-8.725288026013219],"y":[-17.599955954517988],"z":[15.18189853146917],"type":"scatter3d"},{"hovertemplate":"color=dog<br>PC 2 (11.9%)=%{x}<br>PC 3 (11.5%)=%{y}<br>PC 4 (11.4%)=%{z}<extra></extra>","legendgroup":"dog","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"dog","scene":"scene","showlegend":true,"x":[29.260931027875145],"y":[-3.3638034057754282],"z":[35.01627187148528],"type":"scatter3d"},{"hovertemplate":"color=frog<br>PC 2 (11.9%)=%{x}<br>PC 3 (11.5%)=%{y}<br>PC 4 (11.4%)=%{z}<extra></extra>","legendgroup":"frog","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"frog","scene":"scene","showlegend":true,"x":[7.517509485372019],"y":[4.655466386156075],"z":[-3.578304335469645],"type":"scatter3d"},{"hovertemplate":"color=horse<br>PC 2 (11.9%)=%{x}<br>PC 3 (11.5%)=%{y}<br>PC 4 (11.4%)=%{z}<extra></extra>","legendgroup":"horse","marker":{"color":"#B6E880","symbol":"circle"},"mode":"markers","name":"horse","scene":"scene","showlegend":true,"x":[17.455180360168608],"y":[4.859277484630073],"z":[-30.51488544131588],"type":"scatter3d"},{"hovertemplate":"color=ship<br>PC 2 (11.9%)=%{x}<br>PC 3 (11.5%)=%{y}<br>PC 4 (11.4%)=%{z}<extra></extra>","legendgroup":"ship","marker":{"color":"#FF97FF","symbol":"circle"},"mode":"markers","name":"ship","scene":"scene","showlegend":true,"x":[-23.52449549086044],"y":[16.89896808139803],"z":[-12.0747128199556],"type":"scatter3d"},{"hovertemplate":"color=truck<br>PC 2 (11.9%)=%{x}<br>PC 3 (11.5%)=%{y}<br>PC 4 (11.4%)=%{z}<extra></extra>","legendgroup":"truck","marker":{"color":"#FECB52","symbol":"circle"},"mode":"markers","name":"truck","scene":"scene","showlegend":true,"x":[-4.357570357531944],"y":[-30.33148065436279],"z":[-4.4977405608802865],"type":"scatter3d"}],                        {"template":{"data":{"bar":[{"error_x":{"c ...

# %%
plot_pca_matrix(imageSet)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="fd16fe0e-ad10-48f6-8fd7-9480ad8dc0b7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fd16fe0e-ad10-48f6-8fd7-9480ad8dc0b7")) {                    Plotly.newPlot(                        "fd16fe0e-ad10-48f6-8fd7-9480ad8dc0b7",                        [{"dimensions":[{"axis":{"matches":true},"label":"PC 1 (12.2%)","values":[-9.02270203508533]},{"axis":{"matches":true},"label":"PC 2 (11.9%)","values":[-10.828513980991007]},{"axis":{"matches":true},"label":"PC 3 (11.5%)","values":[32.95199824690314]},{"axis":{"matches":true},"label":"PC 4 (11.4%)","values":[14.785141189750895]}],"hovertemplate":"color=airplane<br>%{xaxis.title.text}=%{x}<br>%{yaxis.title.text}=%{y}<extra></extra>","legendgroup":"airplane","marker":{"color":"#636efa","symbol":"circle"},"name":"airplane","showlegend":true,"type":"splom","diagonal":{"visible":false}},{"dimensions":[{"axis":{"matches":true},"label":"PC 1 (12.2%)","values":[19.984159709423004]},{"axis":{"matches":true},"label":"PC 2 (11.9%)","values":[-20.420189630532064]},{"axis":{"matches":true},"label":"PC 3 (11.5%)","values":[4.846001958161038]},{"axis":{"matches":true},"label":"PC 4 (11.4%)","values":[10.124161166470097]}],"hovertemplate":"color=automobile<br>%{xaxis.title.text}=%{x}<br>%{yaxis.title.text}=%{y}<extra></extra>","legendgroup":"automobile","marker":{"color":"#EF553B","symbol":"circle"},"name":"automobile","showlegend":true,"type":"splom","diagonal":{"visible":false}},{"dimensions":[{"axis":{"matches":true},"label":"PC 1 (12.2%)","values":[1.6279494156073688]},{"axis":{"matches":true},"label":"PC 2 (11.9%)","values":[-13.836380604637654]},{"axis":{"matches":true},"label":"PC 3 (11.5%)","values":[-21.815197459404665]},{"axis":{"matches":true},"label":"PC 4 (11.4%)","values":[-9.728295070870267]}],"hovertemplate":"color=bird<br>%{xaxis.title.text}=%{x}<br>%{yaxis.title.text}=%{y}<extra></extra>","legendgroup":"bird","marker":{"color":"#00cc96","symbol":"circle"},"name":"bird","showlegend":true,"type":"splom","diagonal":{"visible":false}},{"dimensions":[{"axis":{"matches":true},"label":"PC 1 (12.2%)","values":[19.908276694282765]},{"axis":{"matches":true},"label":"PC 2 (11.9%)","values":[27.45881721715061]},{"axis":{"matches":true},"label":"PC 3 (11.5%)","values":[8.898725316812206]},{"axis":{"matches":true},"label":"PC 4 (11.4%)","values":[-14.71353453068372]}],"hovertemplate":"color=cat<br>%{xaxis.title.text}=%{x}<br>%{yaxis.title.text}=%{y}<extra></extra>","legendgroup":"cat","marker":{"color":"#ab63fa","symbol":"circle"},"name":"cat","showlegend":true,"type":"splom","diagonal":{"visible":false}},{"dimensions":[{"axis":{"matches":true},"label":"PC 1 (12.2%)","values":[-16.438335992208835]},{"axis":{"matches":true},"label":"PC 2 (11.9%)","values":[-8.725288026013219]},{"axis":{"matches":true},"label":"PC 3 (11.5%)","values":[-17.599955954517988]},{"axis":{"matches":true},"label":"PC 4 (11.4%)","values":[15.18189853146917]}],"hovertemplate":"color=deer<br>%{xaxis.title.text}=%{x}<br>%{yaxis.title.text}=%{y}<extra></extra>","legendgroup":"deer","marker":{"color":"#FFA15A","symbol":"circle"},"name":"deer","showlegend":true,"type":"splom","diagonal":{"visible":false}},{"dimensions":[{"axis":{"matches":true},"label":"PC 1 (12.2%)","values":[-11.887312374897387]},{"axis":{"matches":true},"label":"PC 2 (11.9%)","values":[29.260931027875145]},{"axis":{"matches":true},"label":"PC 3 (11.5%)","values":[-3.3638034057754282]},{"axis":{"matches":true},"label":"PC 4 (11.4%)","values":[35.01627187148528]}],"hovertemplate":"color=dog<br>%{xaxis.title.text}=%{x}<br>%{yaxis.title.text}=%{y}<extra></extra>","legendgroup":"dog","marker":{"color":"#19d3f3","symbol":"circle"},"name":"dog","showlegend":true,"type":"spl ...
